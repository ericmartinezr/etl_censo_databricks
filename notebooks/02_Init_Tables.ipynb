# %% [markdown]
# # Lectura de fuentes e inicialización de tablas

# %% [markdown]
# ## Inicializa Spark

# %%
# %run "./00_Init_Spark"

# %% [markdown]
# ## Setea las variables con las rutas de archivos

# %%
# Cambiar segun donde se este ejecutando
# Esto deberia ser parametrico pero para las pruebas que hago es mucha complejidad
PATH_PARQUET = "/Volumes/censo_workspace/bronze/original/"

# %% [markdown]
# ## Lee archivo Vivienda

# %%
df_vivienda = spark.read.parquet(f"{PATH_PARQUET}/viviendas_censo2024.parquet")
display(df_vivienda)

# %%
df_vivienda.printSchema()

# %% [markdown]
# ## Lee archivo Hogar

# %%
df_hogar = spark.read.parquet(f"{PATH_PARQUET}/hogares_censo2024.parquet")
display(df_hogar)

# %%
df_hogar.printSchema()

# %% [markdown]
# ## Lee archivo Personas

# %%
df_persona = spark.read.parquet(f"{PATH_PARQUET}/personas_censo2024.parquet")
display(df_persona)

# %%
df_persona.printSchema()

# %% [markdown]
# ## Lee archivo de Códigos Territoriales

# %%
df_ct = spark.read.csv(f"{PATH_PARQUET}/codigos_territoriales.csv", sep=",", header=True)

# %%
df_ct.printSchema()

# %% [markdown]
# ## Lee archivo de Códigos Territoriales Específicos

# %%
df_cte = spark.read.csv(f"{PATH_PARQUET}/codigos_territoriales_especificos.csv", sep=",", header=True)

# %%
df_cte.printSchema()

# %% [markdown]
# ## Lee archivo de Códigos Otros

# %%
df_co = spark.read.csv(f"{PATH_PARQUET}/codigos_otros_v2.csv", sep=";", header=True)

# %%
df_co.printSchema()

# %% [markdown]
# ## Validación de total de registros

# %%
df_ct.count()

# %%
df_cte.count()

# %%
df_co.count()

# %%
df_vivienda.count()

# %%
df_hogar.count()

# %%
df_persona.count()

# %% [markdown]
# ## Carga la data de los archivos a las tablas correspondientes

# %%
df_ct.write.insertInto("bronze.codigos_territorios", overwrite=True)

# %%
df_cte.write.insertInto("bronze.codigos_territorios_especificos", overwrite=True)

# %%
df_co.write.insertInto("bronze.codigos_otros", overwrite=True)

# %%
df_vivienda.write.insertInto("bronze.viviendas", overwrite=True)

# %%
df_hogar.write.insertInto("bronze.hogares", overwrite=True)

# %%
df_persona.write.insertInto("bronze.personas", overwrite=True)
